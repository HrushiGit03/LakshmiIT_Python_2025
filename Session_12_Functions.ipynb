# %% [markdown]
# - Functions with out arguments

# %%
# syntax
def <function name>():
    <write your lines here>

# %%
num1=eval(input('Enter the number1:'))
num2=eval(input('Enter the number2:'))
add=num1+num2
print(f'Addition of {num1} and {num2} is : {add}')
# Out:
# Enter the number1: 100
# Enter the number2: 200
# Addition of 100 and 200 is : 300

# %%
def addition():
    num1=eval(input('Enter the number1:'))
    num2=eval(input('Enter the number2:'))
    add=num1+num2
    print(f'Addition of {num1} and {num2} is : {add}')
addition()
# Out:
# Enter the number1: 100
# Enter the number2: 200
# Addition of 100 and 200 is : 300

# %%
# call the function
addition()
# Out:
# Enter the number1: 10
# Enter the number2: 20
# Addition of 10 and 20 is : 30

# %%
def subtraction():
    num1=eval(input('Enter the number1:'))
    num2=eval(input('Enter the number2:'))
    sub=num1-num2
    print(f'Subtraction of {num1} and {num2} is : {sub}')
subtraction()
# Out:
# Enter the number1: 900
# Enter the number2: 200
# Subtraction of 900 and 200 is : 700

# %%
def calcirclearea():
    radious=eval(input('Enter the radious of circle :'))
    area=3.14*radious*radious
    print(f"Area of circle with radius {radious} : {area}")
calcirclearea()
# Out:
# Enter the radious of circle : 20
# Area of circle with radius 20 : 1256.0

# %% [markdown]
# - while defined the function we do not know whether error is there not for that we need to call the function

# %%
def addition1():
    num1=eval(input('Enter the number1:'))
    num2=eval(input('Enter the number2:'))
    add=num11+num2
    print(f'Addition of {num1} and {num2} is : {add}')
addition1()
# Out:
# Enter the number1: 100
# Enter the number2: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4     add=num11+num2
#       5     print(f'Addition of {num1} and {num2} is : {add}')
# ----> 6 addition1()
#
# Cell In[23], line 4, in addition1()
#       2 num1=eval(input('Enter the number1:'))
#       3 num2=eval(input('Enter the number2:'))
# ----> 4 add=num11+num2
#       5 print(f'Addition of {num1} and {num2} is : {add}')
#
# NameError: name 'num11' is not defined

# %%
try:
    def addition2():
        n1=eval(input('Enter the number1:'))
        n2=eval(input('Enter the number2:'))
        add=n11+n2
        print(f'Addition of {num1} and {num2} is : {add}')
except Exception as e:
    print(e)
addition2()
# Out:
# Enter the number1: 100
# Enter the number2: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       7 except Exception as e:
#       8     print(e)
# ----> 9 addition2()
#
# Cell In[25], line 5, in addition2()
#       3 n1=eval(input('Enter the number1:'))
#       4 n2=eval(input('Enter the number2:'))
# ----> 5 add=n11+n2
#       6 print(f'Addition of {num1} and {num2} is : {add}')
#
# NameError: name 'n11' is not defined

# %%
def addition3():
    try:
        n1=eval(input('Enter the number1:'))
        n2=eval(input('Enter the number2:'))
        add=n11+n2
        print(f'Addition of {num1} and {num2} is : {add}')
    except Exception as e:
        print(e)
addition3()
# Out:
# Enter the number1: 200
# Enter the number2: 300
# name 'n11' is not defined

# %% [markdown]
# - tr-except should  write inside the function

# %% [markdown]
# **Functions with arguments**

# %%
- How many varaables are there inside the function
-

# %%
def addition4(n1,n2):
    try:
        print('n1',n1)
        print('n2',n2)
        add=n1+n2
        print(f'Addition of {n1} and {n2} is : {add}')
    except Exception as e:
        print(e)
addition4(90,100)
# Out:
# n1 90
# n2 100
# Addition of 90 and 100 is : 190

# %%
def addition5(n1):
    try:
        n2=eval(input('Enter the number n2:'))
        add=n1+n2
        print(f'Addition of {n1} and {n2} is : {add}')
    except Exception as e:
        print(e)
addition5(105)
# Out:
# Enter the number n2: 80
# Addition of 105 and 80 is : 185

# %%
def AVG(n1,n2,n3):
    try:
        avg=(n1+n2+n3)/3
        avg=round(avg,2)
        print(f"Avg {avg}:")
    except Exception as e:
        print('Exp came',e)
AVG(10,30,50)
# Out:
# Avg 30.0:

# %%
#function with default argument
# 6)wap ask the user the random bill amount and tip percentage
#    take tip percentage as 10
#   calculate total bill= bill amount+ bill amount*tip per/100
#   var1: bill amount var2: tip amount
#    formuale
def bill_amount_with_percent(billamount,tippercent=20):
                                        toalbill=billamount+(billamount*tippercent/100)
                                        print(f"The total bill amount {billamount} is with TIP percent {tippercent} % formulae : {toalbill}")
bill_amount_with_percent(5000)
# Out:
# The total bill amount 5000 is with TIP percent 20 % formulae : 6000.0

# %%
#function with default arguments overiding the default value
# 6)wap ask the user the random bill amount and tip percentage
#    take tip percentage as 10
#   calculate total bill= bill amount+ bill amount*tip per/100
#   var1: bill amount var2: tip amount
#    formuale
def bill_amount_with_percent(billamount,tippercent=20):
                                        toalbill=billamount+(billamount*tippercent/100)
                                        print(f"The total bill amount {billamount} is with TIP percent {tippercent} % formulae : {toalbill}")
bill_amount_with_percent(5000,30)
# Out:
# The total bill amount 5000 is with TIP percent 30 % formulae : 6500.0

# %%
#n3 deafult value with functsions
def avg(n1,n2,n3=40):
        avg_val=(n1+n2+n3)/3
        avg_val=round(avg_val,2)
        print(f"The average of {n1},{n2} and {n3} is :{avg_val}")
avg(90,100)
# Out:
# The average of 90,100 and 40 is :76.67

# %%
#n2,n3 deafult value functions
def avg(n1,n2=20,n3=40):
        avg_val=(n1+n2+n3)/3
        avg_val=round(avg_val,2)
        print(f"The average of {n1},{n2} and {n3} is :{avg_val}")
avg(90)
# Out:
# The average of 90,20 and 40 is :50.0

# %%
#n2,n3 deafult value functions
def avg(n1=20,n2=20,n3=40):
        avg_val=(n1+n2+n3)/3
        avg_val=round(avg_val,2)
        print(f"The average of {n1},{n2} and {n3} is :{avg_val}")
avg(20)
# Out:
# The average of 20,20 and 40 is :26.67

# %%
**Defaulut argumets at last alwalys**
# Out:
#   Cell In[23], line 1
#     **Defaulut argumets at last alwalys**
#     ^
# SyntaxError: invalid syntax

# %%
#n2,n3 deafult value functions
def avg(n1,n2=20,n3):
        avg_val=(n1+n2+n3)/3
        avg_val=round(avg_val,2)
        print(f"The average of {n1},{n2} and {n3} is :{avg_val}")
avg(90,20)
# Out:
#   Cell In[1], line 2
#     def avg(n1,n2=20,n3):
#                      ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
#wap ask the user to enter a number

def verify_even_odd():
    global num
    num=eval(input('Enter the number :'))
    if(num %2==0):
        print(f'{num} is an even')
    else:
        print(f'{num} is odd')

verify_even_odd()
# Out:
# Enter the number : 10
# 10 is even

# %%
# function with arhumnent

def verify_even_odd(num1):
    if(num1 %2==0):
        print(f'{num1} is an even')
    else:
        print(f'{num1} is an odd')

verify_even_odd(10)
# Out:
# 10 is even

# %%
global num1
def verify_even_odd(num1=15):
    if(num1 %2==0):
        print(f'{num1} is an even')
    else:
        print(f'{num1} is an odd')

verify_even_odd()
# Out:
# 15 is an odd

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 num
#
# NameError: name 'num' is not defined

# %% [markdown]
# **Parameter vs varaible**
# - Parameters also called as Arguments
# - This always inside the functions
# - varaiable either outside function or inside the functions

# %% [markdown]
# ** return **
# - return means function is giving some thing
# - we know local varaibles outside the fuction , we have two methods
# - inorder to use local varaibles ,we have methods
# - global
# - return

# %%
def add():
    a=10
    b=20
    c=a+b
    return(c) # return the value or print here 
add()
# Out:
# 30

# %%
def add():
    a=10
    b=20
    global c
    c=a+b
    print(c)
add()
# Out:
# 30

# %%
c
# Out:
# 30

# %%
def add():
    a=10
    b=20
    c=a+b
    return(a,c) # return the value or print here 
a=add() #tuple
a,c=add()
print(a)
print(a,c)
# Out:
# 10
# 10 30

# %%
val1,val2=10
val1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 val1,val2=10
#       2 val1
#
# TypeError: cannot unpack non-iterable int object

# %%
def avg(a,b,c):
    sum=a+b+c
    avg1=sum/3
    return(sum,avg1)
summ,avg2=avg(10,20,30)
summ,avg2
# Out:
# (60, 20.0)

# %%
def avg(a,b,c):
    sum=a+b+c
    avg1=sum/3
    return(sum,avg1)
summ,avg2=avg(10,20,30)
sum
avg2
# Out:
# 20.0

# %%
#wap ask the user to enter a number and verfy the number is even or odd and return 
def verify_even_odd():
        num=eval(input('Enter the number :'))
        if(num %2==0):
            val1=10
            print(f'{num} is an even')
            return (num+10)
        else:
            val1=20
            print(f'{num} is odd')
            return (num+20)

x=verify_even_odd()
x
# Out:
# Enter the number : 1001
# 1001 is odd
# 1021

# %% [markdown]
# **Function in function**

# %%
def greet1():
    print('Hello good morning')
def greet2():
    print('Hello good night')
greet1()
greet2()
# Out:
# Hello good morning
# Hello good night

# %%
def greet1():
    print('Hello good morning')
    greet2()

def greet2():
    print('Hello good night')

greet1()
# Out:
# Hello good morning
# Hello good night

# %%
def greet1():
    print('Hello good morning')
    #greet2()

def greet2():
    print('Hello good night')
    greet1()

greet2()
# Out:
# Hello good night
# Hello good morning

# %%
def greet1():
    print('Hello good morning')
    greet2()
 
def greet2():
    print('Hello good night')
greet1()
# Out:
# Hello good morning
# Hello good night

# %%
def greet11():
    print('Hello good morning')
    greet22()
 
def greet22():
    print('Hello good night')
greet11()
# Out:
# Hello good morning
# Hello good night

# %%
def greet11():
        print('Hello good morning')
        greet22()
 
def greet22():
         print('Hello good night')
         greet11()
greet11()
# Out:
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# Hello good morning
# Hello good night
# ...

# %%
def greet3():
    print('I do not what Iam doing')
    greet3()
greet3()
# Out:
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# I do not what Iam doing
# ...

# %%
def add(n):
    if(n==0):
        return(0)
    else:
        return(n+add(n-1))
add(5)
#step 1: n=5 if F else 5+add(5-1)
        #n=4 if else 5+4+(4-1)
       # n=3 if else 5+4+3+(3-1)
    #n=2 if else 5+4+3+(2-1)
      #  n=0 if true
        #total : 15
# Out:
# 15
